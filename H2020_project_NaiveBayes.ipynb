# %% [markdown]
# ## H2020 project objective analyse using ML

# %% [markdown]
# Starting from data published by the commission on H2020 projects at https://data.europa.eu/euodp/en/data/dataset/cordisH2020projects we do some data mining.
#
# Now we try ML using Naive Bayes on a dataset containing textile projects & nontextile projects

# %% [markdown]
# ##### Creating the dataset

# %%
import pandas as pd
import csv

#modules for NLP
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

from collections import Counter

# %% [markdown]
# ##### Dataset files were downloaded locally
#
# reports = pd.read_csv('C:/Users/jl/Downloads/h2020reports.csv', sep= ";", encoding='LATIN1') <br/>
# organisations = pd.read_csv('C:/Users/jl/Downloads/h2020organizations.csv', sep= ";", encoding='LATIN1', ) <br/>
# deliverables = pd.read_csv('C:/Users/jl/Downloads/h2020projectDeliverables.csv', sep= ";",encoding='LATIN1') <br/>
# projects = pd.read_csv('C:/Users/jl/Downloads/h2020projects.csv', sep= ";",encoding='LATIN1')

# %%
projects = pd.read_csv('C:/Users/jl/Downloads/h2020projects.csv', sep= ";",encoding='UTF-8')
programmes = pd.read_csv('C:/Users/jl/Downloads/h2020programmes.csv', sep= ";",encoding='UTF-8')
topics = pd.read_csv('C:/Users/jl/Downloads/h2020topics.csv', sep= ";",encoding='LATIN1')

# %%
# concatenize programmes & topics
topics_programmes = pd.concat([programmes,topics], sort = False)

# %%
topics_programmes.head()
# Out:
#       rcn               code  \
# 0  664357      H2020-EU.3.4.
# 1  664321      H2020-EU.3.3.
# 2  664233  H2020-EU.2.3.2.3.
# 3  664281      H2020-EU.3.2.
# 4  664235        H2020-EU.3.
#
#                                                title  \
# 0  RETOS DE LA SOCIEDAD - Transporte inteligente,...
# 1  WYZWANIA SPOŁECZNE - Bezpieczna, czysta i efek...
# 2                       Wsparcie innowacji rynkowych
# 3  RETOS DE LA SOCIEDAD - Seguridad alimentaria, ...
# 4                        PRIORITÉ «Défis de société»
#
#                                           shortTitle language
# 0                                          Transport       es
# 1                                             Energy       pl
# 2                Supporting market-driven innovation       pl
# 3  Food, agriculture, forestry, marine research a...       es
# 4                                Societal Challenges       fr

# %%
# Total number of projects in the file
print("Total number of projects in file is {}".format(len(projects)))
# Out:
# Total number of projects in file is 24554

# %%
# Adding programme and topic information on the textile projects
data = pd.merge(projects, topics_programmes, how='left', left_on ="topics", right_on ="code")
data.drop(['code','language', 'rcn_x','rcn_y','id','subjects','shortTitle'], axis=1, inplace=True)
data.rename(columns = {'title_x': 'titleProject','title_y':'callTitle'}, inplace=True)

# %%
data.head()
# Out:
#         acronym  status                        programme  \
# 0       FARMYNG  SIGNED  H2020-EU.2.1.4.;H2020-EU.3.2.6.
# 1        FF-IPM  SIGNED                H2020-EU.3.2.1.1.
# 2       BELENUS  SIGNED                  H2020-EU.3.3.2.
# 3  RURALIZATION  SIGNED                H2020-EU.3.2.1.3.
# 4         iLIVE  SIGNED                  H2020-EU.3.1.3.
#
#                   topics frameworkProgramme  \
# 0        BBI.2018.SO3.F2              H2020
# 1  SFS-05-2018-2019-2020              H2020
# 2     LC-SC3-RES-11-2018              H2020
# 3       RUR-01-2018-2019              H2020
# 4        SC1-BHC-23-2018              H2020
#
#                                         titleProject   startDate     endDate  \
# 0  FlAgship demonstration of industrial scale pro...  2019-06-01  2022-06-30
# 1  In-silico boosted, pest prevention and off-sea...  2019-09-01  2023-08-31
# 2  Lowering Costs by Improving Efficiencies in Bi...  2019-03-01  2023-02-28
# 3  The opening of rural areas to renew rural gene...  2019-05-01  2023-04-30
# 4  Living well, dying well. A research programme ...  2019-01-01  2022-12-31
#
#   projectUrl                                          objective   totalCost  \
# 0        NaN  The world faces a major challenge with the sha...  46934849,1
# 1        NaN  The FF-IPM project targets three highly polyph...   6004252,5
# 2        NaN  The primary objective of BELENUS is to lower b...  4991323,75
# 3        NaN  European economic, social and territorial cohe...     5995904
# 4        NaN  Every year around 4 million people die in the ...   4108817,5
#
#   ecMaxContribution                             call fundingScheme  \
# 0       19630411,18               H2020-BBI-JTI-2018   BBI-IA-FLAG
# 1         6004252,5                 H2020-SFS-2018-2           RIA
# 2        4991323,75  H2020-LC-SC3-2018-RES-TwoStages           RIA
# 3           5995904                 H2020-RUR-2018-2           RIA
# 4         4017817,5  H2020-SC1-2018-Single-Stage-RTD           RIA
#
#                                       coordinator coordinatorCountry  \
# 0                                          YNSECT                 FR
# 1                         PANEPISTIMIO THESSALIAS                 EL
# 2               UNIVERSIDAD COMPLUTENSE DE MADRID                 ES
# 3                   TECHNISCHE UNIVERSITEIT DELFT                 NL
# 4  ERASMUS UNIVERSITAIR MEDISCH CENTRUM ROTTERDAM                 NL
#
#                                         participants  \
# 0  EUROFINS ANALYTICS FRANCE SAS;VIRBAC NUTRITION...
# 1  UNIVERSITAT JAUME I DE CASTELLON;ANECOOP SOCIE...
# 2  EIFER EUROPAISCHES INSTITUT FUR ENERGIEFORSCHU...
# 3  MAGYAR TUDOMANYOS AKADEMIA TARSADALOMTUDOMANYI...
# 4  MEDIZINISCHE UNIVERSITAET WIEN;KLINIKUM DER UN...
#
#                               participantCountries  \
# 0                          FR;NO;BE;ES;PL;CH;DE;NL
# 1  ES;PT;HR;IL;DE;PL;AT;ZA;IT;BE;EL;CY;FR;US;AU;CN
# 2                             DE;ES;FI;PT;UK;SE;FR
# 3                 HU;FR;IE;PL;DE;RO;ES;UK;BE;FI;IT
# 4           AT;DE;SE;AU;NZ;CH;NL;SI;UK;ES;IS;NO;AR
#
#                                            callTitle
# 0  Large-scale production of proteins for food an...
# 1             New and emerging risks to plant health
# 2  Developing solutions to reduce the cost and in...
# 3  Building modern rural policies on long-term vi...
# 4  Novel patient-centred approaches for survivors...

# %%
# Selecting the projects which have the words textiles or clothing in the objectives
data['lobjective'] = data['objective'].str.lower()
data['memberTrainingSet'] = False
data['textileProject'] = False
terms = ['textile','textiles','clothing']
terms = '|'.join(terms)
data.loc[data['lobjective'].str.contains(terms, na=False),'memberTrainingSet'] = True
data.loc[data['lobjective'].str.contains(terms, na=False),'textileProject'] = True
print("Total number of textile & clothing related projects is {}".format(data['memberTrainingSet'].sum()))
# Out:
# Total number of textile & clothing related projects is 188

# %%
# selecting 200 random samples from non-textiles projects
import random
ran = data.loc[data['memberTrainingSet'] == 0].sample(n=200)
data.loc[data.index.isin(ran.index),'memberTrainingSet'] = True

# %%
data.head()
# Out:
#         acronym  status                        programme  \
# 0       FARMYNG  SIGNED  H2020-EU.2.1.4.;H2020-EU.3.2.6.
# 1        FF-IPM  SIGNED                H2020-EU.3.2.1.1.
# 2       BELENUS  SIGNED                  H2020-EU.3.3.2.
# 3  RURALIZATION  SIGNED                H2020-EU.3.2.1.3.
# 4         iLIVE  SIGNED                  H2020-EU.3.1.3.
#
#                   topics frameworkProgramme  \
# 0        BBI.2018.SO3.F2              H2020
# 1  SFS-05-2018-2019-2020              H2020
# 2     LC-SC3-RES-11-2018              H2020
# 3       RUR-01-2018-2019              H2020
# 4        SC1-BHC-23-2018              H2020
#
#                                         titleProject   startDate     endDate  \
# 0  FlAgship demonstration of industrial scale pro...  2019-06-01  2022-06-30
# 1  In-silico boosted, pest prevention and off-sea...  2019-09-01  2023-08-31
# 2  Lowering Costs by Improving Efficiencies in Bi...  2019-03-01  2023-02-28
# 3  The opening of rural areas to renew rural gene...  2019-05-01  2023-04-30
# 4  Living well, dying well. A research programme ...  2019-01-01  2022-12-31
#
#   projectUrl                                          objective  ...  \
# 0        NaN  The world faces a major challenge with the sha...  ...
# 1        NaN  The FF-IPM project targets three highly polyph...  ...
# 2        NaN  The primary objective of BELENUS is to lower b...  ...
# 3        NaN  European economic, social and territorial cohe...  ...
# 4        NaN  Every year around 4 million people die in the ...  ...
#
#                               call fundingScheme  \
# 0               H2020-BBI-JTI-2018   BBI-IA-FLAG
# 1                 H2020-SFS-2018-2           RIA
# 2  H2020-LC-SC3-2018-RES-TwoStages           RIA
# 3                 H2020-RUR-2018-2           RIA
# 4  H2020-SC1-2018-Single-Stage-RTD           RIA
#
#                                       coordinator coordinatorCountry  \
# 0                                          YNSECT                 FR
# 1                         PANEPISTIMIO THESSALIAS                 EL
# 2               UNIVERSIDAD COMPLUTENSE DE MADRID                 ES
# 3                   TECHNISCHE UNIVERSITEIT DELFT                 NL
# 4  ERASMUS UNIVERSITAIR MEDISCH CENTRUM ROTTERDAM                 NL
#
#                                         participants  \
# 0  EUROFINS ANALYTICS FRANCE SAS;VIRBAC NUTRITION...
# 1  UNIVERSITAT JAUME I DE CASTELLON;ANECOOP SOCIE...
# 2  EIFER EUROPAISCHES INSTITUT FUR ENERGIEFORSCHU...
# 3  MAGYAR TUDOMANYOS AKADEMIA TARSADALOMTUDOMANYI...
# 4  MEDIZINISCHE UNIVERSITAET WIEN;KLINIKUM DER UN...
#
#                               participantCountries  \
# 0                          FR;NO;BE;ES;PL;CH;DE;NL
# 1  ES;PT;HR;IL;DE;PL;AT;ZA;IT;BE;EL;CY;FR;US;AU;CN
# 2                             DE;ES;FI;PT;UK;SE;FR
# 3                 HU;FR;IE;PL;DE;RO;ES;UK;BE;FI;IT
# 4           AT;DE;SE;AU;NZ;CH;NL;SI;UK;ES;IS;NO;AR
#
#                                            callTitle  \
# 0  Large-scale production of proteins for food an...
# 1             New and emerging risks to plant health
# 2  Developing solutions to reduce the cost and in...
# 3  Building modern rural policies on long-term vi...
# 4  Novel patient-centred approaches for survivors...
#
#                                           lobjective memberTrainingSet  \
# 0  the world faces a major challenge with the sha...             False
# 1  the ff-ipm project targets three highly polyph...             False
# 2  the primary objective of belenus is to lower b...             False
# 3  european economic, social and territorial cohe...             False
# 4  every year around 4 million people die in the ...             False
#
#   textileProject
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 22 columns]

# %%
dataX = data.loc[data['memberTrainingSet'] == True, :]
dataX.to_csv('training.csv', sep = ";")

# %% [markdown]
# ### Using ML
#
# The dataset of samples is saved and the textile projects are reviewed to make sure that they are textile projects. Of course here start the discussion : 'What is a textile project ?". The data is stored on disk in a file 'training_corrected.csv'.

# %%
dataX = pd.read_csv('training_corrected.csv', sep=';', index_col=0)
dataX = dataX[dataX['memberTrainingSet'] == True]
dataX
# Out:
#                   acronym      status  \
# 4                   iLIVE      SIGNED
# 42             CORRO STOP      SIGNED
# 3759              1D-Neon      SIGNED
# 291           INTELLICONT      SIGNED
# 14517           3DAddChip      SIGNED
# 348                Co-VAL      SIGNED
# 373            EPIDIVERSE      SIGNED
# 16900      3DConfigurator      SIGNED
# 10322                 ACE      CLOSED
# 563                   M2M      CLOSED
# 16115             AeroPul      SIGNED
# 2964               ALDing      SIGNED
# 13317               APOLO      SIGNED
# 22787                APRA      SIGNED
# 11630        ArcInTex ETN      SIGNED
# 1165               BMX-11      CLOSED
# 14374           BIOMOTIVE      SIGNED
# 1302              REFOCUS      CLOSED
# 16988             BIOnTop      SIGNED
# 1383             LASERFIT      CLOSED
# 1413                LEMON      SIGNED
# 19214            Bioprene      CLOSED
# 6580             BIOXYARN  TERMINATED
# 1523   SAFEIMMUNOSUPPRESS      CLOSED
# 17695            BodyPass      SIGNED
# 19503         CARBIDE2500      SIGNED
# 1698             PELLETON      CLOSED
# 421                   CGM      CLOSED
# 1708         FAST SPECTRO      CLOSED
# 1825           ThyroTrust      CLOSED
# ...                   ...         ...
# 21943         Quipu Cloud      CLOSED
# 22058            PHELLINI      CLOSED
# 22099             GARDair      SIGNED
# 19287           VisuaLook      CLOSED
# 22154   AuNP-PhotoBioDrug      SIGNED
# 2300            We TAP IN      CLOSED
# 22500        H2Bio2Energy      SIGNED
# 21239             WEAFING      SIGNED
# 22616            LODALORD      SIGNED
# 23911                WEAP      SIGNED
# 23025            OsciLang      SIGNED
# 23146          FriendCoop      SIGNED
# 23155            NEMoCuRe      SIGNED
# 10108                WEAR      SIGNED
# 23248            simpetmr      SIGNED
# 1366             WearMark      CLOSED
# 23526              HySTOC      SIGNED
# 8557            Wearonics      SIGNED
# 12775            WEARPLEX      SIGNED
# 3160            wellwatch      CLOSED
# 13131            XIMOFILM      CLOSED
# 23968            GeoBrown      SIGNED
# 24019           GLOTRAINS      SIGNED
# 24121     MYCONEUTROPHILS      SIGNED
# 4822               XoSoft      SIGNED
# 24166          SOUNDBITES      SIGNED
# 24181          EARTHBLOOM      SIGNED
# 17153           YARNSCAPE      SIGNED
# 24190            GREENLOC      SIGNED
# 19930           ZYMVOLVER      CLOSED
#
#                                                programme  \
# 4                                        H2020-EU.3.1.3.
# 42               H2020-EU.3.;H2020-EU.2.3.;H2020-EU.2.1.
# 3759                                     H2020-EU.2.1.3.
# 291                                    H2020-EU.3.4.5.1.
# 14517                                      H2020-EU.1.1.
# 348                                      H2020-EU.3.6.3.
# 373                                      H2020-EU.1.3.1.
# 16900            H2020-EU.3.;H2020-EU.2.3.;H2020-EU.2.1.
# 10322                    H2020-EU.2.3.1.;H2020-EU.2.1.2.
# 563                      H2020-EU.2.1.6.;H2020-EU.2.3.1.
# 16115                                  H2020-EU.3.4.5.1.
# 2964                                     H2020-EU.1.3.2.
# 13317                                    H2020-EU.3.3.2.
# 22787                                      H2020-EU.1.1.
# 11630                                    H2020-EU.1.3.1.
# 1165     H2020-EU.3.2.5.;H2020-EU.3.2.3.;H2020-EU.2.3.1.
# 14374                                    H2020-EU.3.2.6.
# 1302                     H2020-EU.2.1.6.;H2020-EU.2.3.1.
# 16988                    H2020-EU.2.1.4.;H2020-EU.3.2.6.
# 1383                     H2020-EU.2.3.1.;H2020-EU.2.1.2.
# 1413                                     H2020-EU.3.3.7.
# 19214                      H2020-EU.3.5.;H2020-EU.2.3.1.
# 6580                                     H2020-EU.1.3.2.
# 1523                                       H2020-EU.1.1.
# 17695                                    H2020-EU.2.1.1.
# 19503            H2020-EU.3.;H2020-EU.2.3.;H2020-EU.2.1.
# 1698                       H2020-EU.3.3.;H2020-EU.2.3.1.
# 421    H2020-EU.2.1.5.;H2020-EU.2.1.3.;H2020-EU.2.3.1...
# 1708                                       H2020-EU.1.1.
# 1825                                     H2020-EU.3.1.3.
# ...                                                  ...
# 21943                    H2020-EU.2.1.1.;H2020-EU.2.3.1.
# 22058                                    H2020-EU.1.3.2.
# 22099                                    H2020-EU.3.1.3.
# 19287                    H2020-EU.2.1.1.;H2020-EU.2.3.1.
# 22154                                    H2020-EU.1.3.2.
# 2300                     H2020-EU.2.3.1.;H2020-EU.2.1.2.
# 22500                                    H2020-EU.1.3.2.
# 21239                                    H2020-EU.2.1.1.
# 22616                                    H2020-EU.1.3.2.
# 23911                                    H2020-EU.1.3.2.
# 23025                                      H2020-EU.1.1.
# 23146                                    H2020-EU.1.3.2.
# 23155                                    H2020-EU.1.3.2.
# 10108                                    H2020-EU.2.1.1.
# 23248                                    H2020-EU.1.3.2.
# 1366                     H2020-EU.2.1.1.;H2020-EU.2.3.1.
# 23526                H2020-EU.3.3.8.2.;H2020-EU.3.3.8.3.
# 8557                                     H2020-EU.1.3.2.
# 12775                                    H2020-EU.2.1.1.
# 3160                     H2020-EU.2.1.1.;H2020-EU.2.3.1.
# 13131            H2020-EU.3.;H2020-EU.2.3.;H2020-EU.2.1.
# 23968                                      H2020-EU.1.1.
# 24019                                    H2020-EU.1.3.2.
# 24121                                    H2020-EU.1.3.2.
# 4822                                     H2020-EU.2.1.1.
# 24166                                    H2020-EU.1.3.2.
# 24181                                      H2020-EU.1.1.
# 17153                                    H2020-EU.1.3.2.
# 24190                                    H2020-EU.1.3.2.
# 19930            H2020-EU.3.;H2020-EU.2.3.;H2020-EU.2.1.
#
#                              topics frameworkProgramme  \
# 4                   SC1-BHC-23-2018              H2020
# 42            EIC-SMEInst-2018-2020              H2020
# 3759                    NMP-22-2015              H2020
# 291    JTI-CS2-2017-CFP06-LPA-02-16              H2020
# 14517                  ERC-2018-COG              H2020
# 348          CULT-COOP-11-2016-2017              H2020
# 373                   MSCA-ITN-2017              H2020
# 16900         EIC-SMEInst-2018-2020              H2020
# 10322                   NMP-25-2015              H2020
# 563            SMEInst-04-2016-2017              H2020
# 16115  JTI-CS2-2015-CFP02-LPA-02-10              H2020
# 2964                   MSCA-IF-2016              H2020
# 13317              LCE-07-2016-2017              H2020
# 22787                  ERC-2017-ADG              H2020
# 11630             MSCA-ITN-2014-ETN              H2020
# 1165           SMEInst-08-2016-2017              H2020
# 14374                  BBI-2016-D05              H2020
# 1302           SMEInst-04-2016-2017              H2020
# 16988              BBI.2018.SO3.R10              H2020
# 1383                  NMP-25-2015-1              H2020
# 1413                     EE-20-2015              H2020
# 19214                 SC5-20-2014-1              H2020
# 6580                MSCA-IF-2014-EF              H2020
# 1523                   ERC-PoC-2015              H2020
# 17695              ICT-14-2016-2017              H2020
# 19503         EIC-SMEInst-2018-2020              H2020
# 1698                  SIE-01-2015-1              H2020
# 421            SMEInst-02-2016-2017              H2020
# 1708                   ERC-PoC-2015              H2020
# 1825                  PHC-12-2015-1              H2020
# ...                             ...                ...
# 21943          SMEInst-01-2016-2017              H2020
# 22058               MSCA-IF-2014-EF              H2020
# 22099          SMEInst-05-2016-2017              H2020
# 19287                 ICT-37-2014-1              H2020
# 22154               MSCA-IF-2014-EF              H2020
# 2300                  NMP-25-2015-1              H2020
# 22500                  MSCA-IF-2016              H2020
# 21239                   ICT-02-2018              H2020
# 22616                  MSCA-IF-2016              H2020
# 23911                  MSCA-IF-2016              H2020
# 23025                  ERC-2017-PoC              H2020
# 23146                  MSCA-IF-2017              H2020
# 23155                  MSCA-IF-2017              H2020
# 10108                   ICT-36-2016              H2020
# 23248                  MSCA-IF-2017              H2020
# 1366                  ICT-37-2015-1              H2020
# 23526                 FCH-02-6-2017              H2020
# 8557                   MSCA-IF-2016              H2020
# 12775                   ICT-02-2018              H2020
# 3160           SMEInst-01-2016-2017              H2020
# 13131         EIC-SMEInst-2018-2020              H2020
# 23968                  ERC-2016-ADG              H2020
# 24019                  MSCA-IF-2016              H2020
# 24121               MSCA-IF-2015-EF              H2020
# 4822                    ICT-24-2015              H2020
# 24166                  MSCA-IF-2016              H2020
# 24181                  ERC-2016-STG              H2020
# 17153                  MSCA-IF-2018              H2020
# 24190                  MSCA-IF-2016              H2020
# 19930         EIC-SMEInst-2018-2020              H2020
#
#                                             titleProject   startDate  \
# 4      Living well, dying well. A research programme ...   1/01/2019
# 42     EDS 2500 - Cold degassing of boiler water for ...   1/09/2018
# 3759                 1D Nanofibre Electro-Optic Networks   1/04/2016
# 291    Development and Manufacturing of Intelligent L...   1/03/2018
# 14517  Additive manufacturing of 2D nanomaterials for...   1/09/2019
# 348    Understanding value co-creation in public serv...   1/11/2017
# 373                      Epigenetic Diversity in Ecology   1/09/2017
# 16900  Fully-automated software platform with 3D free...   1/05/2019
# 10322  ANNULUS CLOSURE EXPANDABLE DEVICE BASED ON SHA...   1/10/2015
# 563                                    mapKITE to market   1/04/2017
# 16115  Curved profiles for aerospace applications man...   1/09/2016
# 2964   Novel industrial processes using the Atomic La...   1/04/2017
# 13317  SmArt Designed Full Printed Flexible RObust Ef...   1/04/2018
# 22787  Active Polymers for Renewable Functional Actua...   1/10/2018
# 11630                                       ArcInTex ETN   1/01/2015
# 1165   Providing Antifouling Additives for Marine Pai...   1/09/2016
# 14374  Advanced BIObased polyurethanes and fibres for...   1/06/2017
# 1302   ‘Plug And Play’ Forest Asset Monitoring Servic...   1/05/2016
# 16988  Novel packaging films and textiles with tailor...   1/06/2019
# 1383   Laser cladding for the recovery of critical to...   1/03/2016
# 1413                LEMON Less Energy More OpportuNities   1/02/2016
# 19214  Bio-based high-purity isoprene through high-yi...   1/04/2015
# 6580   In vitro evaluation of the biocompatibility of...   1/12/2015
# 1523   Development of immunosuppressive treatments wi...   1/01/2016
# 17695  API-ecosystem for cross-sectorial exchange of ...   1/01/2018
# 19503  The first 2500°C industrial furnace, for highe...   1/05/2018
# 1698   PELLETON – a device for production of pellets ...   1/12/2015
# 421    A next generation nanomedia that can be tailor...   1/06/2017
# 1708             Spatially Multiplexed Spectrophotometry   1/11/2015
# 1825   A novel reliable diagnostic device to avoid un...   1/02/2016
# ...                                                  ...         ...
# 21943  A suite of software applications hosted in the...   1/08/2017
# 22058  Plasmonic Heaters Linked to Lanthanide-Based N...   1/11/2015
# 22099  The first predictive in vitro assay for the id...   1/03/2017
# 19287  Novel clothing e-commerce application for reli...   1/02/2015
# 22154  Functionalized AuNPs and their use for biologi...  13/05/2015
# 2300   Weaving Technology based Automated Production ...   1/07/2015
# 22500  Operando FTIR spectro-electrochemistry of hydr...   8/01/2018
# 21239  Wearable Electroactive Fabrics Integrated in G...   1/01/2019
# 22616           Local Diversity and Long-Run Development   1/09/2017
# 23911             The Western European Acheulian Project   1/09/2017
# 23025  OsciLang: A neurofeedback system based on osci...   1/10/2018
# 23146  The role of friendship in cooperation: a compa...   1/08/2019
# 23155  Role of S-Nitrosylation of epigenetic modifier...   1/09/2018
# 10108  Wearable technologists Engage with Artists for...   1/01/2017
# 23248  Development of quantification procedures for s...   1/05/2018
# 1366   New approach to Wearable devices wireless perf...   1/03/2016
# 23526  Hydrogen Supply and Transportation using liqui...   1/01/2018
# 8557   Developing Stretchable Conductive Fibres and t...   1/04/2017
# 12775         Wearable multiplexed biomedical electrodes   1/01/2019
# 3160   A hands-free remote monitoring solution for co...   1/02/2017
# 13131  The first ultra-low extractable silicone film ...   1/08/2018
# 23968  Brownian geometry: at the interface between pr...   1/05/2017
# 24019          Global Transitions and Innovation Systems   1/06/2017
# 24121  Elucidating the involvement of neutrophils in ...   1/03/2017
# 4822   Soft modular biomimetic exoskeleton to assist ...   1/02/2016
# 24166  Sound it out: inferring foraging ecology from ...  14/05/2018
# 24181  Earth’s first biological bloom: An integrated ...   1/02/2017
# 17153  YARNSCAPE: Ecological Economies of Ancient Tex...   1/08/2020
# 24190  A High-Sensitive Green Localization System for...   1/08/2017
# 19930  Launching A Unified Cloud-Based Platform for N...   1/06/2018
#
#           endDate                                         projectUrl  \
# 4      31/12/2022                                                NaN
# 42     28/02/2019                                                NaN
# 3759   31/03/2020                             http://www.1d-neon.eu/
# 291    28/02/2021                                                NaN
# 14517  31/08/2024                                                NaN
# 348    31/10/2020                              http://www.co-val.eu/
# 373    31/08/2021                                                NaN
# 16900  30/04/2021                                                NaN
# 10322  30/09/2018  http://www.neosurgery.com/index.php/en/r-d-pro...
# 563    30/09/2017  http://mapkite.com/index.php/markets-business/...
# 16115  30/06/2019                                                NaN
# 2964   31/03/2019  http://ctechnano.com/coating-technologies/aldi...
# 13317  31/03/2022                                                NaN
# 22787  30/09/2023                                                NaN
# 11630  28/02/2019      http://www.arcintexetn.eu/www.arcintexetn.com
# 1165   31/12/2016             http://biomimetx.wixsite.com/biomimetx
# 14374  31/05/2021                            https://biomotive.info/
# 1302   30/09/2016                                                NaN
# 16988  31/05/2023                                                NaN
# 1383   31/08/2016                   http://www.gnclaser.es/index.php
# 1413   31/01/2020                       http://www.lemon-project.eu/
# 19214  31/07/2015              http://www.cyclotronroad.org/visolis/
# 6580   30/11/2017                         http://www.irb.hr/BIOXYARN
# 1523   30/06/2017                                                NaN
# 17695  31/12/2020                                                NaN
# 19503  30/04/2020                                                NaN
# 1698   31/05/2016                                http://pelleton.pl/
# 421    30/09/2017                            http://www.customem.com
# 1708   30/04/2017                                                NaN
# 1825   31/07/2016                             http://www.genomnia.it
# ...           ...                                                ...
# 21943  31/12/2017                               http://www.quipu.eu/
# 22058  31/10/2017                   http://www.bionanoplasmonics.com
# 22099  28/02/2019                            http://www.senzagen.com
# 19287  31/07/2015                           http://tecnologiasdim.es
# 22154  12/05/2017                    https://portal.uea.ac.uk/search
# 2300   31/01/2016                               http://www.sbe-bv.nl
# 22500   7/01/2020                                                NaN
# 21239  30/06/2023                                                NaN
# 22616  31/08/2020                                                NaN
# 23911  31/08/2019                                                NaN
# 23025  31/03/2020                                                NaN
# 23146  31/07/2022                                                NaN
# 23155  31/08/2020                                                NaN
# 10108  28/02/2019                            https://wearsustain.eu/
# 23248  30/04/2020                                                NaN
# 1366   31/08/2016                            http://www.verkotan.com
# 23526  31/12/2020                                                NaN
# 8557   31/03/2019                                                NaN
# 12775  31/12/2021                                                NaN
# 3160   30/04/2017                        http://www.smartlifeinc.com
# 13131  30/11/2018                        https://www.cpi-plasma.com/
# 23968  30/04/2022                                                NaN
# 24019  31/05/2019                                                NaN
# 24121  28/02/2019                                                NaN
# 4822   31/01/2019                               http://www.xosoft.eu
# 24166  13/05/2020                                                NaN
# 24181  31/01/2022                                                NaN
# 17153  31/07/2022                                                NaN
# 24190  31/07/2019                                                NaN
# 19930  30/09/2018                              http://www.zymvol.com
#
#                                                objective  ...  \
# 4      Every year around 4 million people die in the ...  ...
# 42     Wherever heat is When heat is needed (for indu...  ...
# 3759   The vision of 1D-NEON proposal is to develop f...  ...
# 291    Air cargo has experienced tremendous growth. E...  ...
# 14517  The realization of “the internet of things” is...  ...
# 348    The main goal of Co-VAL is to discover, analys...  ...
# 373    Plants are the foundation of all ecosystems an...  ...
# 16900  Mass customization is finding its way into inn...  ...
# 10322  The objective of the ACE project is to broaden...  ...
# 563    The goal of M2M is to conduct a market analysi...  ...
# 16115  This proposal addresses the topic JTI-CS2-2015...  ...
# 2964   Different from chemical vapor deposition (CVD)...  ...
# 13317  Perovskite solar cells (PSC) have shown an imp...  ...
# 22787  The idea of mechanical actuator based on intri...  ...
# 11630  A fundamental challenge in design research tod...  ...
# 1165   90% of antifouling paints contain copper and s...  ...
# 14374  Vehicles are composed by different materials a...  ...
# 1302   Regio, a leading provider of GIS solutions in ...  ...
# 16988  Only 31% of plastic is currently recycled and ...  ...
# 1383   'Car manufacturers have developed and incorpor...  ...
# 1413   'LEMON 'Less Energy More OpportuNities' focuss...  ...
# 19214  Visolis represent the future in cheap sustaina...  ...
# 6580   'Fibres and textiles have been used as biomate...  ...
# 1523   The idea of the proposal is to prove the relev...  ...
# 17695  BodyPass aims to break barriers between health...  ...
# 19503  With nearly 50 years of experience and holding...  ...
# 1698   Biomass, like fossil fuels, releases CO2 when ...  ...
# 421    Customem Ltd is a company founded in 2014 with...  ...
# 1708   As a result of the research undertaken in the ...  ...
# 1825   Fine needle aspiration cytology (FNAC) is the ...  ...
# ...                                                  ...  ...
# 21943  Medical Ultrasound today is considered as a ma...  ...
# 22058  This project addresses the quest of new materi...  ...
# 22099  The GARDair project will optimize and validate...  ...
# 19287  E-commerce has become a focal point of expansi...  ...
# 22154  The development of gold nanostructures is a to...  ...
# 2300   The Weaving Technology based Automated Product...  ...
# 22500  Ongoing search for renewable energy technologi...  ...
# 21239  WEAFING will develop innovative garments with ...  ...
# 22616  Social scientists have long studied the effect...  ...
# 23911  The Western European Acheulean Project (WEAP) ...  ...
# 23025  The goal of OsciLang is to provide an affordab...  ...
# 23146  Diverse lines of theoretical and empirical res...  ...
# 23155  This MSCA-IF describes a career development pl...  ...
# 10108  Wearable technologies aimed at private consume...  ...
# 23248  Imaging of physiological functions in the livi...  ...
# 1366   Wearable devices, such as smart glasses, smart...  ...
# 23526  Hydrogen is a versatile energy carrier that wi...  ...
# 8557   Europe needs to take action to develop stretch...  ...
# 12775  WEARPLEX is a multidisciplinary research and i...  ...
# 3160   Cardiovascular disease (CVD) is the leading ca...  ...
# 13131  Today, silicone contamination is one of the ma...  ...
# 23968  The main purpose of this proposal is to explor...  ...
# 24019  World development is at a critical turning poi...  ...
# 24121  Tuberculosis has afflicted humans for about 70...  ...
# 4822   The XoSoft project will develop a modular soft...  ...
# 24166  Like many seabirds, penguins face the challeng...  ...
# 24181  The origin of oxygenic photosynthesis is one o...  ...
# 17153  “YARNSCAPE: ecological economies of ancient te...  ...
# 24190  Among the main goals of Intelligent Transporta...  ...
# 19930  Actually, global enzymes market is today €8.18...  ...
#
#                                      call  fundingScheme  \
# 4         H2020-SC1-2018-Single-Stage-RTD            RIA
# 42              H2020-SMEInst-2018-2020-1          SME-1
# 3759             H2020-NMP-2015-two-stage             IA
# 291               H2020-CS2-CFP06-2017-01         CS2-IA
# 14517                        ERC-2018-COG        ERC-COG
# 348    H2020-SC6-CULT-COOP-2017-one-stage            RIA
# 373                   H2020-MSCA-ITN-2017   MSCA-ITN-ETN
# 16900           H2020-SMEInst-2018-2020-2          SME-2
# 10322                H2020-SMEINST-2-2015          SME-2
# 563             H2020-SMEINST-1-2016-2017          SME-1
# 16115             H2020-CS2-CFP02-2015-01         CS2-IA
# 2964                   H2020-MSCA-IF-2016  MSCA-IF-EF-SE
# 13317     H2020-LCE-2017-RES-RIA-TwoStage            RIA
# 22787                        ERC-2017-ADG        ERC-ADG
# 11630                 H2020-MSCA-ITN-2014   MSCA-ITN-ETN
# 1165            H2020-SMEINST-1-2016-2017          SME-1
# 14374                  H2020-BBI-JTI-2016    BBI-IA-DEMO
# 1302            H2020-SMEINST-1-2016-2017          SME-1
# 16988                  H2020-BBI-JTI-2018        BBI-RIA
# 1383                 H2020-SMEINST-1-2015          SME-1
# 1413                  H2020-EE-2015-4-PDA            CSA
# 19214                H2020-SMEINST-1-2014          SME-1
# 6580                   H2020-MSCA-IF-2014  MSCA-IF-EF-ST
# 1523                         ERC-2015-PoC        ERC-POC
# 17695                    H2020-ICT-2017-1             IA
# 19503           H2020-SMEInst-2018-2020-2          SME-2
# 1698                 H2020-SMEINST-1-2015          SME-1
# 421             H2020-SMEINST-1-2016-2017          SME-1
# 1708                         ERC-2015-PoC        ERC-POC
# 1825                 H2020-SMEINST-1-2015          SME-1
# ...                                   ...            ...
# 21943           H2020-SMEINST-1-2016-2017          SME-1
# 22058                  H2020-MSCA-IF-2014  MSCA-IF-EF-ST
# 22099           H2020-SMEINST-2-2016-2017          SME-2
# 19287                H2020-SMEINST-1-2014          SME-1
# 22154                  H2020-MSCA-IF-2014  MSCA-IF-EF-ST
# 2300                 H2020-SMEINST-1-2015          SME-1
# 22500                  H2020-MSCA-IF-2016  MSCA-IF-EF-ST
# 21239                    H2020-ICT-2018-2            RIA
# 22616                  H2020-MSCA-IF-2016     MSCA-IF-GF
# 23911                  H2020-MSCA-IF-2016  MSCA-IF-EF-ST
# 23025                        ERC-2017-PoC        ERC-POC
# 23146                  H2020-MSCA-IF-2017     MSCA-IF-GF
# 23155                  H2020-MSCA-IF-2017  MSCA-IF-EF-ST
# 10108                    H2020-ICT-2016-1             IA
# 23248                  H2020-MSCA-IF-2017  MSCA-IF-EF-SE
# 1366                 H2020-SMEINST-1-2015          SME-1
# 23526                H2020-JTI-FCH-2017-1       FCH2-RIA
# 8557                   H2020-MSCA-IF-2016  MSCA-IF-EF-ST
# 12775                    H2020-ICT-2018-2            RIA
# 3160            H2020-SMEINST-1-2016-2017          SME-1
# 13131           H2020-SMEInst-2018-2020-1          SME-1
# 23968                        ERC-2016-ADG        ERC-ADG
# 24019                  H2020-MSCA-IF-2016  MSCA-IF-EF-ST
# 24121                  H2020-MSCA-IF-2015  MSCA-IF-EF-ST
# 4822                       H2020-ICT-2015            RIA
# 24166                  H2020-MSCA-IF-2016  MSCA-IF-EF-ST
# 24181                        ERC-2016-STG        ERC-STG
# 17153                  H2020-MSCA-IF-2018  MSCA-IF-EF-ST
# 24190                  H2020-MSCA-IF-2016  MSCA-IF-EF-ST
# 19930           H2020-SMEInst-2018-2020-1          SME-1
#
#                                              coordinator coordinatorCountry  \
# 4         ERASMUS UNIVERSITAIR MEDISCH CENTRUM ROTTERDAM                 NL
# 42                                            EKOWA GMBH                 DE
# 3759   THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                 UK
# 291    SKANDINAVIAN ABIONIX GKRIS ANONIMIETAREIA EMPO...                 EL
# 14517  IMPERIAL COLLEGE OF SCIENCE TECHNOLOGY AND MED...                 UK
# 348    ATHENS TECHNOLOGY CENTER ANONYMI BIOMICHANIKI ...                 EL
# 373    KONINKLIJKE NEDERLANDSE AKADEMIE VAN WETENSCHA...                 NL
# 16900                                       OKINLAB GMBH                 DE
# 10322                                    NEOS SURGERY SL                 ES
# 563                                       GEONUMERICS SL                 ES
# 16115                            FASERINSTITUT BREMEN EV                 DE
# 2964                             COATING TECHNOLOGIES SL                 ES
# 13317           ACONDICIONAMIENTO TARRASENSE ASSOCIACION                 ES
# 22787  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                 UK
# 11630                                 HOEGSKOLAN I BORAS                 SE
# 1165                                       BIOMIMETX, SA                 PT
# 14374  SELENA LABS SPOLKA Z OGRANICZONA ODPOWIEDZIALN...                 PL
# 1302                                          AS REACH-U                 EE
# 16988  AIMPLAS - ASOCIACION DE INVESTIGACION DE MATER...                 ES
# 1383                       GRUPO NICOLAS CORREA LASER SA                 ES
# 1413   AGENZIA PER L'ENERGIA E LO SVILUPPO SOSTENIBIL...                 IT
# 19214                           VISOLIS TECHNOLOGIES LTD                 UK
# 6580                            RUDER BOSKOVIC INSTITUTE                 HR
# 1523   INSTITUT NATIONAL DE LA SANTE ET DE LA RECHERC...                 FR
# 17695               INSTITUTO DE BIOMECANICA DE VALENCIA                 ES
# 19503                   CREMER THERMOPROZESSANLAGEN GMBH                 DE
# 1698   ZAKLADY URZADZEN KOTLOWYCH STAPORKOW SPOLKA AK...                 PL
# 421                                         CUSTOMEM LTD                 UK
# 1708   AGENCIA ESTATAL CONSEJO SUPERIOR DEINVESTIGACI...                 ES
# 1825                                        GENOMNIA SRL                 IT
# ...                                                  ...                ...
# 21943                                          QUIPU SRL                 IT
# 22058  ASOCIACION CENTRO DE INVESTIGACION COOPERATIVA...                 ES
# 22099                                        SENZAGEN AB                 SE
# 19287                                 TECNOLOGIAS DIM SL                 ES
# 22154                          UNIVERSITY OF EAST ANGLIA                 UK
# 2300                 SUSTAINABLE BUSINESS ENGINEERS B.V.                 NL
# 22500  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                 UK
# 21239                                UNIVERSITEIT TWENTE                 NL
# 22616                             KOBENHAVNS UNIVERSITET                 DK
# 23911                                     BRITISH MUSEUM                 UK
# 23025  BCBL BASQUE CENTER ON COGNITION BRAIN AND LANG...                 ES
# 23146  GEORG-AUGUST-UNIVERSITAT GOTTINGENSTIFTUNG OFF...                 DE
# 23155                        THE UNIVERSITY OF EDINBURGH                 UK
# 10108        INTERUNIVERSITAIR MICRO-ELECTRONICA CENTRUM                 BE
# 23248                                 REGION HOVEDSTADEN                 DK
# 1366                                         VERKOTAN OY                 FI
# 23526                     HYDROGENIOUS TECHNOLOGIES GMBH                 DE
# 8557                        ISTANBUL TEKNIK UNIVERSITESI                 TR
# 12775                          UNIVERSITY OF SOUTHAMPTON                 UK
# 3160                                SMARTLIFEINC LIMITED                 UK
# 13131                      COATING PLASMA INNOVATION SAS                 FR
# 23968                               UNIVERSITE PARIS-SUD                 FR
# 24019                               UNIVERSITEIT UTRECHT                 NL
# 24121  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                 UK
# 4822          FONDAZIONE ISTITUTO ITALIANO DI TECNOLOGIA                 IT
# 24166  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                 FR
# 24181  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                 FR
# 17153             Institut Català d'Arqueologia Clàssica                 ES
# 24190                     CHALMERS TEKNISKA HOEGSKOLA AB                 SE
# 19930                              ZYMVOL BIOMODELING SL                 ES
#
#                                             participants  \
# 4      MEDIZINISCHE UNIVERSITAET WIEN;KLINIKUM DER UN...
# 42                                                   NaN
# 3759   SAATI SPA;HENKEL KGaA;BIOAGE SRL;CENTITVC - CE...
# 291    THE UNIVERSITY OF MANCHESTER;NATIONAL TECHNICA...
# 14517                                                NaN
# 348    BUDAPESTI CORVINUS EGYETEM;UNIVERSITA COMMERCI...
# 373    PHILIPPS UNIVERSITAET MARBURG;MARTIN-LUTHER-UN...
# 16900                                                NaN
# 10322                                                NaN
# 563                                                  NaN
# 16115          THOMAS GMBH + CO. TECHNIK + INNOVATION KG
# 2964                                                 NaN
# 13317  UNIVERSITA DEGLI STUDI DI ROMA TOR VERGATA;FRA...
# 22787                                                NaN
# 11630  VILNIAUS DAILES AKADEMIJA;AB LUDVIG SVENSSON;U...
# 1165                                                 NaN
# 14374  NOVAMONT SPA;PATENTOPOLIS BV;LEDA POLYMER SP Z...
# 1302                                                 NaN
# 16988  SIOEN INDUSTRIES NV;CENTRE SCIENTIFIQUE & TECH...
# 1383                                                 NaN
# 1413   AZIENDA CASA EMILIA ROMAGNA DELLA PROVINCIA DI...
# 19214                                      BIOSPHERE SRL
# 6580                                                 NaN
# 1523                                                 NaN
# 17695  FUNDACION PARA LA INVESTIGACION DEL HOSPITAL C...
# 19503                                                NaN
# 1698                                                 NaN
# 421                                                  NaN
# 1708                                                 NaN
# 1825                                                 NaN
# ...                                                  ...
# 21943                                                NaN
# 22058                                                NaN
# 22099                                                NaN
# 19287                                                NaN
# 22154                                                NaN
# 2300                                                 NaN
# 22500                                                NaN
# 21239  LINKOPINGS UNIVERSITET;WEARABLE TECHNOLOGIES A...
# 22616                                                NaN
# 23911                                                NaN
# 23025                                                NaN
# 23146                                                NaN
# 23155                                                NaN
# 10108  DIGITAL SPACES LIVING LAB OOD;BLUMINE SRL;WE C...
# 23248                                                NaN
# 1366                                                 NaN
# 23526  OY WOIKOSKI AB;FRIEDRICH-ALEXANDER-UNIVERSITAE...
# 8557                                                 NaN
# 12775  ABALONYX AS;FUNDACION TECNALIA RESEARCH & INNO...
# 3160                                                 NaN
# 13131                                                NaN
# 23968                                                NaN
# 24019                                                NaN
# 24121                                                NaN
# 4822   STICHTING SAXION;ROESSINGH RESEARCH AND DEVELO...
# 24166                                                NaN
# 24181                                LAKEHEAD UNIVERSITY
# 17153                                                NaN
# 24190                                                NaN
# 19930                                                NaN
#
#                          participantCountries  \
# 4      AT;DE;SE;AU;NZ;CH;NL;SI;UK;ES;IS;NO;AR
# 42                                        NaN
# 3759                        IT;DE;PT;UK;ES;NL
# 291                                  UK;EL;ES
# 14517                                     NaN
# 348             HU;IT;BE;NL;NO;DK;FR;ES;DE;UK
# 373                      DE;CH;CZ;ES;IT;AT;FR
# 16900                                     NaN
# 10322                                     NaN
# 563                                       NaN
# 16115                                      DE
# 2964                                      NaN
# 13317                    IT;DE;FR;CH;PT;ES;EL
# 22787                                     NaN
# 11630                          LT;SE;DE;UK;NL
# 1165                                      NaN
# 14374                 IT;NL;PL;DE;FI;BE;ES;RO
# 1302                                      NaN
# 16988                 BE;ES;NL;IT;CZ;EE;DE;HR
# 1383                                      NaN
# 1413                                       IT
# 19214                                      IT
# 6580                                      NaN
# 1523                                      NaN
# 17695                             ES;IT;PT;NL
# 19503                                     NaN
# 1698                                      NaN
# 421                                       NaN
# 1708                                      NaN
# 1825                                      NaN
# ...                                       ...
# 21943                                     NaN
# 22058                                     NaN
# 22099                                     NaN
# 19287                                     NaN
# 22154                                     NaN
# 2300                                      NaN
# 22500                                     NaN
# 21239                             SE;DE;FR;NL
# 22616                                     NaN
# 23911                                     NaN
# 23025                                     NaN
# 23146                                     NaN
# 23155                                     NaN
# 10108                          BG;IT;BE;DE;UK
# 23248                                     NaN
# 1366                                      NaN
# 23526                                FI;DE;NL
# 8557                                      NaN
# 12775                    NO;ES;SE;FI;DE;CH;DK
# 3160                                      NaN
# 13131                                     NaN
# 23968                                     NaN
# 24019                                     NaN
# 24121                                     NaN
# 4822                        NL;IS;IE;ES;DE;CH
# 24166                                     NaN
# 24181                                      CA
# 17153                                     NaN
# 24190                                     NaN
# 19930                                     NaN
#
#                                                callTitle  \
# 4      Novel patient-centred approaches for survivors...
# 42                                        SME instrument
# 3759   Fibre-based materials for non-clothing applica...
# 291                                       SmartContainer
# 14517                             ERC Consolidator Grant
# 348    Understanding the transformation of European p...
# 373                         Innovative Training Networks
# 16900                                     SME instrument
# 10322  Accelerating the uptake of nanotechnologies, a...
# 563      Engaging SMEs in space research and development
# 16115  Development of pultrusion manufacturing applic...
# 2964                              Individual Fellowships
# 13317  Developing the next generation technologies of...
# 22787                                 ERC Advanced Grant
# 11630  Marie Skłodowska-Curie Innovative Training Net...
# 1165   Supporting SMEs efforts for the development - ...
# 14374  Bio-based polymers/plastic materials with new ...
# 1302     Engaging SMEs in space research and development
# 16988  Develop bio-based packaging products that are ...
# 1383   Accelerating the uptake of nanotechnologies, a...
# 1413   Project development assistance for innovative ...
# 19214  Boosting the potential of small businesses for...
# 6580   Marie Skłodowska-Curie Individual Fellowships ...
# 1523                          ERC Proof of Concept Grant
# 17695  Big Data PPP: cross-sectorial and cross-lingua...
# 19503                                     SME instrument
# 1698   Stimulating the innovation potential of SMEs f...
# 421    Accelerating the uptake of nanotechnologies ad...
# 1708                          ERC Proof of Concept Grant
# 1825   Clinical research for the validation of biomar...
# ...                                                  ...
# 21943                  Open Disruptive Innovation Scheme
# 22058  Marie Skłodowska-Curie Individual Fellowships ...
# 22099  Supporting innovative SMEs in the healthcare b...
# 19287  Open Disruptive Innovation Scheme (implemented...
# 22154  Marie Skłodowska-Curie Individual Fellowships ...
# 2300   Accelerating the uptake of nanotechnologies, a...
# 22500                             Individual Fellowships
# 21239                  Flexible and Wearable Electronics
# 22616                             Individual Fellowships
# 23911                             Individual Fellowships
# 23025                               ERC-Proof of Concept
# 23146                             Individual Fellowships
# 23155                             Individual Fellowships
# 10108  Boost synergies between artists, creative peop...
# 23248                             Individual Fellowships
# 1366   Open Disruptive Innovation Scheme (implemented...
# 23526                    Liquid organic hydrogen carrier
# 8557                              Individual Fellowships
# 12775                  Flexible and Wearable Electronics
# 3160                   Open Disruptive Innovation Scheme
# 13131                                     SME instrument
# 23968                                 ERC Advanced Grant
# 24019                             Individual Fellowships
# 24121  Marie Skłodowska-Curie Individual Fellowships ...
# 4822                                            Robotics
# 24166                             Individual Fellowships
# 24181                                 ERC Starting Grant
# 17153                             Individual Fellowships
# 24190                             Individual Fellowships
# 19930                                     SME instrument
#
#                                               lobjective memberTrainingSet  \
# 4      every year around 4 million people die in the ...              True
# 42     wherever heat is when heat is needed (for indu...              True
# 3759   the vision of 1d-neon proposal is to develop f...              True
# 291    air cargo has experienced tremendous growth. e...              True
# 14517  the realization of “the internet of things” is...              True
# 348    the main goal of co-val is to discover, analys...              True
# 373    plants are the foundation of all ecosystems an...              True
# 16900  mass customization is finding its way into inn...              True
# 10322  the objective of the ace project is to broaden...              True
# 563    the goal of m2m is to conduct a market analysi...              True
# 16115  this proposal addresses the topic jti-cs2-2015...              True
# 2964   different from chemical vapor deposition (cvd)...              True
# 13317  perovskite solar cells (psc) have shown an imp...              True
# 22787  the idea of mechanical actuator based on intri...              True
# 11630  a fundamental challenge in design research tod...              True
# 1165   90% of antifouling paints contain copper and s...              True
# 14374  vehicles are composed by different materials a...              True
# 1302   regio, a leading provider of gis solutions in ...              True
# 16988  only 31% of plastic is currently recycled and ...              True
# 1383   'car manufacturers have developed and incorpor...              True
# 1413   'lemon 'less energy more opportunities' focuss...              True
# 19214  visolis represent the future in cheap sustaina...              True
# 6580   'fibres and textiles have been used as biomate...              True
# 1523   the idea of the proposal is to prove the relev...              True
# 17695  bodypass aims to break barriers between health...              True
# 19503  with nearly 50 years of experience and holding...              True
# 1698   biomass, like fossil fuels, releases co2 when ...              True
# 421    customem ltd is a company founded in 2014 with...              True
# 1708   as a result of the research undertaken in the ...              True
# 1825   fine needle aspiration cytology (fnac) is the ...              True
# ...                                                  ...               ...
# 21943  medical ultrasound today is considered as a ma...              True
# 22058  this project addresses the quest of new materi...              True
# 22099  the gardair project will optimize and validate...              True
# 19287  e-commerce has become a focal point of expansi...              True
# 22154  the development of gold nanostructures is a to...              True
# 2300   the weaving technology based automated product...              True
# 22500  ongoing search for renewable energy technologi...              True
# 21239  weafing will develop innovative garments with ...              True
# 22616  social scientists have long studied the effect...              True
# 23911  the western european acheulean project (weap) ...              True
# 23025  the goal of oscilang is to provide an affordab...              True
# 23146  diverse lines of theoretical and empirical res...              True
# 23155  this msca-if describes a career development pl...              True
# 10108  wearable technologies aimed at private consume...              True
# 23248  imaging of physiological functions in the livi...              True
# 1366   wearable devices, such as smart glasses, smart...              True
# 23526  hydrogen is a versatile energy carrier that wi...              True
# 8557   europe needs to take action to develop stretch...              True
# 12775  wearplex is a multidisciplinary research and i...              True
# 3160   cardiovascular disease (cvd) is the leading ca...              True
# 13131  today, silicone contamination is one of the ma...              True
# 23968  the main purpose of this proposal is to explor...              True
# 24019  world development is at a critical turning poi...              True
# 24121  tuberculosis has afflicted humans for about 70...              True
# 4822   the xosoft project will develop a modular soft...              True
# 24166  like many seabirds, penguins face the challeng...              True
# 24181  the origin of oxygenic photosynthesis is one o...              True
# 17153  “yarnscape: ecological economies of ancient te...              True
# 24190  among the main goals of intelligent transporta...              True
# 19930  actually, global enzymes market is today €8.18...              True
#
#       textileProject
# 4              False
# 42             False
# 3759            True
# 291            False
# 14517           True
# 348            False
# 373            False
# 16900           True
# 10322           True
# 563            False
# 16115          False
# 2964            True
# 13317          False
# 22787           True
# 11630          False
# 1165           False
# 14374           True
# 1302           False
# 16988           True
# 1383           False
# 1413           False
# 19214          False
# 6580            True
# 1523           False
# 17695          False
# 19503          False
# 1698           False
# 421            False
# 1708           False
# 1825           False
# ...              ...
# 21943          False
# 22058          False
# 22099          False
# 19287           True
# 22154          False
# 2300           False
# 22500          False
# 21239           True
# 22616          False
# 23911          False
# 23025          False
# 23146          False
# 23155          False
# 10108           True
# 23248          False
# 1366           False
# 23526          False
# 8557            True
# 12775           True
# 3160            True
# 13131          False
# 23968          False
# 24019          False
# 24121          False
# 4822            True
# 24166          False
# 24181          False
# 17153          False
# 24190          False
# 19930          False
#
# [388 rows x 22 columns]

# %%
model_data = dataX.loc[dataX['memberTrainingSet'] == True,['lobjective','textileProject']]
model_data['textileProject']=model_data['textileProject'].map({True : 1, False : 0})

# %%
from nltk.stem import WordNetLemmatizer
tokenizer = RegexpTokenizer(r'\w+\D+.\D+')
wordnet_lemmatizer = WordNetLemmatizer()
stopWords = set(stopwords.words('english'))

# %%
def my_tokenizer(s):
    tokens = tokenizer.tokenize(s)
    tokens = [t for t in tokens if len(t) > 2] 
    tokens = [wordnet_lemmatizer.lemmatize(t) for t in tokens]
    tokens = [t for t in tokens if t not in stopWords]
    return tokens

# %%
def tokens_to_vector(tokens, label):
    x = np.zeros(len(word_index_map) + 1) # last element is for the label
    for t in tokens:
        i = word_index_map[t]
        x[i] += 1
    x = x / x.sum() # normalize it before setting label
    x[-1] = label
    return x

# %%
word_index_map = {}
current_index = 0
orig_reviews = []
textile_tokens = []
nontextile_tokens = []

for obj in model_data.loc[model_data['textileProject'] == 1,'lobjective']:
    orig_reviews.append(obj)
    tokens = my_tokenizer(obj)
    textile_tokens.append(tokens)

    for token in tokens:
        if token not in word_index_map:
            word_index_map[token] = current_index
            current_index += 1
            
for obj in model_data.loc[model_data['textileProject'] == 0,'lobjective']:
    orig_reviews.append(obj)
    tokens = my_tokenizer(obj)
    nontextile_tokens.append(tokens)

    for token in tokens:
        if token not in word_index_map:
            word_index_map[token] = current_index
            current_index += 1

# %%
import numpy as np
data = np.zeros((len(textile_tokens)+len(nontextile_tokens),len(word_index_map)+1))
i=0

for tokens in textile_tokens:
    x = tokens_to_vector(tokens,1)
    data[i,:] = x
    i +=1
    
for tokens in nontextile_tokens:
    x = tokens_to_vector(tokens,0)
    data[i,:] = x
    i +=1

# %%
from sklearn.utils import shuffle
orig_reviews, data = shuffle(orig_reviews, data)

# %%
data.shape
# Out:
# (388, 1464)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier

X = data[:,:-1]
Y = data[:,-1]

X.shape
Y.shape

CV = CountVectorizer(encoding = 'LATIN1')
#Xf = CV.fit_transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, shuffle = True, train_size = 0.8)

#model = AdaBoostClassifier()
#model = MultinomialNB()
model = LogisticRegression(solver = 'lbfgs')
model.fit(X_train, Y_train)

print("Classification rate for NB:", model.score(X_test, Y_test))
# Out:
# Classification rate for NB: 0.6538461538461539
